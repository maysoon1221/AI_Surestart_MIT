# %%
import keras
from keras import layers

# This is the size of our encoded representations
encoding_dim = 32  # 32 floats -> compression of factor 24.5, assuming the input is 784 floats

# This is our input image
input_img = keras.Input(shape=(784,))
# "encoded" is the encoded representation of the input
encoded = layers.Dense(encoding_dim, activation='relu')(input_img)
# "decoded" is the lossy reconstruction of the input
decoded = layers.Dense(784, activation='sigmoid')(encoded)

# This model maps an input to its reconstruction
autoencoder = keras.Model(input_img, decoded)

# %%
# This model maps an input to its encoded representation
encoder = keras.Model(input_img, encoded)

# %%
# This is our encoded (32-dimensional) input
encoded_input = keras.Input(shape=(encoding_dim,))
# Retrieve the last layer of the autoencoder model
decoder_layer = autoencoder.layers[-1]
# Create the decoder model
decoder = keras.Model(encoded_input, decoder_layer(encoded_input))

# %%
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# %%
from keras.datasets import mnist
import numpy as np
(x_train, _), (x_test, _) = mnist.load_data()

# %%
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))
print(x_train.shape)
print(x_test.shape)
# Out:
# (60000, 784)
# (10000, 784)

# %%
autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Epoch 1/50
# 235/235 [==============================] - 24s 11ms/step - loss: 0.3855 - val_loss: 0.1903
# Epoch 2/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1811 - val_loss: 0.1543
# Epoch 3/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1497 - val_loss: 0.1338
# Epoch 4/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1315 - val_loss: 0.1217
# Epoch 5/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1206 - val_loss: 0.1136
# Epoch 6/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1134 - val_loss: 0.1075
# Epoch 7/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1077 - val_loss: 0.1033
# Epoch 8/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1035 - val_loss: 0.1000
# Epoch 9/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1008 - val_loss: 0.0974
# Epoch 10/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0980 - val_loss: 0.0957
# Epoch 11/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0965 - val_loss: 0.0945
# Epoch 12/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0955 - val_loss: 0.0938
# Epoch 13/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0950 - val_loss: 0.0933
# Epoch 14/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0946 - val_loss: 0.0930
# Epoch 15/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0941 - val_loss: 0.0927
# Epoch 16/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0939 - val_loss: 0.0926
# Epoch 17/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0937 - val_loss: 0.0924
# Epoch 18/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0935 - val_loss: 0.0923
# Epoch 19/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0936 - val_loss: 0.0922
# Epoch 20/50
# 235/235 [==============================] - 2s 6ms/step - loss: 0.0936 - val_loss: 0.0921
# Epoch 21/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0931 - val_loss: 0.0921
# Epoch 22/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0934 - val_loss: 0.0921
# Epoch 23/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0930 - val_loss: 0.0920
# Epoch 24/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0929 - val_loss: 0.0919
# Epoch 25/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0931 - val_loss: 0.0919
# Epoch 26/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0930 - val_loss: 0.0919
# Epoch 27/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0930 - val_loss: 0.0918
# Epoch 28/50
# 235/235 [==============================] - ETA: 0s - loss: 0.092 - 2s 7ms/step - loss: 0.0929 - val_loss: 0.0918
# Epoch 29/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0928 - val_loss: 0.0918
# Epoch 30/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0928 - val_loss: 0.0919
# Epoch 31/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0930 - val_loss: 0.0918
# Epoch 32/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0929 - val_loss: 0.0917
# Epoch 33/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0929 - val_loss: 0.0917
# Epoch 34/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0929 - val_loss: 0.0917
# Epoch 35/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0928 - val_loss: 0.0918
# Epoch 36/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0928 - val_loss: 0.0917
# Epoch 37/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0925 - val_loss: 0.0917
# Epoch 38/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0927 - val_loss: 0.0916
# Epoch 39/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0926 - val_loss: 0.0916
# Epoch 40/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0926 - val_loss: 0.0917
# Epoch 41/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0926 - val_loss: 0.0916
# Epoch 42/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0925 - val_loss: 0.0916
# Epoch 43/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0926 - val_loss: 0.0916
# Epoch 44/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0928 - val_loss: 0.0916
# Epoch 45/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0927 - val_loss: 0.0916
# Epoch 46/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0927 - val_loss: 0.0916
# Epoch 47/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0926 - val_loss: 0.0915
# Epoch 48/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0925 - val_loss: 0.0915
# Epoch 49/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0926 - val_loss: 0.0915
# Epoch 50/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0926 - val_loss: 0.0915

# %%
# Encode and decode some digits
# Note that we take them from the *test* set
encoded_imgs = encoder.predict(x_test)
decoded_imgs = decoder.predict(encoded_imgs)

# %%
# Use Matplotlib (don't ask)
import matplotlib.pyplot as plt

n = 10  # How many digits we will display
plt.figure(figsize=(20, 4))
for i in range(n):
    # Display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
from keras import regularizers

encoding_dim = 32

input_img = keras.Input(shape=(784,))
# Add a Dense layer with a L1 activity regularizer
encoded = layers.Dense(encoding_dim, activation='relu',
                activity_regularizer=regularizers.l1(10e-5))(input_img)
decoded = layers.Dense(784, activation='sigmoid')(encoded)

autoencoder = keras.Model(input_img, decoded)

# %%
input_img = keras.Input(shape=(784,))
encoded = layers.Dense(128, activation='relu')(input_img)
encoded = layers.Dense(64, activation='relu')(encoded)
encoded = layers.Dense(32, activation='relu')(encoded)

decoded = layers.Dense(64, activation='relu')(encoded)
decoded = layers.Dense(128, activation='relu')(decoded)
decoded = layers.Dense(784, activation='sigmoid')(decoded)

# %%
autoencoder = keras.Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

autoencoder.fit(x_train, x_train,
                epochs=100,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Epoch 1/100
# 235/235 [==============================] - 4s 10ms/step - loss: 0.3380 - val_loss: 0.1691
# Epoch 2/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1616 - val_loss: 0.1387
# Epoch 3/100
# 235/235 [==============================] - ETA: 0s - loss: 0.136 - 2s 10ms/step - loss: 0.1362 - val_loss: 0.1250
# Epoch 4/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1249 - val_loss: 0.1186
# Epoch 5/100
# 235/235 [==============================] - 3s 11ms/step - loss: 0.1183 - val_loss: 0.1134
# Epoch 6/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.1140 - val_loss: 0.1101
# Epoch 7/100
# 235/235 [==============================] - 2s 11ms/step - loss: 0.1110 - val_loss: 0.1073
# Epoch 8/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1081 - val_loss: 0.1056
# Epoch 9/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.1062 - val_loss: 0.1032
# Epoch 10/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.1040 - val_loss: 0.1014
# Epoch 11/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.1021 - val_loss: 0.0997
# Epoch 12/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1009 - val_loss: 0.0985
# Epoch 13/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0992 - val_loss: 0.0979
# Epoch 14/100
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0982 - val_loss: 0.0969
# Epoch 15/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0974 - val_loss: 0.0954
# Epoch 16/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0959 - val_loss: 0.0945
# Epoch 17/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0953 - val_loss: 0.0938
# Epoch 18/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0946 - val_loss: 0.0935
# Epoch 19/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0938 - val_loss: 0.0924
# Epoch 20/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0933 - val_loss: 0.0921
# Epoch 21/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0926 - val_loss: 0.0915
# Epoch 22/100
# 235/235 [==============================] - 2s 11ms/step - loss: 0.0920 - val_loss: 0.0909
# Epoch 23/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0917 - val_loss: 0.0906
# Epoch 24/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0912 - val_loss: 0.0904
# Epoch 25/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0909 - val_loss: 0.0897
# Epoch 26/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0903 - val_loss: 0.0894
# Epoch 27/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0900 - val_loss: 0.0895
# Epoch 28/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0897 - val_loss: 0.0889
# Epoch 29/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0893 - val_loss: 0.0887
# Epoch 30/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0889 - val_loss: 0.0881
# Epoch 31/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0887 - val_loss: 0.0879
# Epoch 32/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0883 - val_loss: 0.0876
# Epoch 33/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0879 - val_loss: 0.0872
# Epoch 34/100
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0877 - val_loss: 0.0871
# Epoch 35/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0876 - val_loss: 0.0868
# Epoch 36/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0873 - val_loss: 0.0864
# Epoch 37/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0870 - val_loss: 0.0864
# Epoch 38/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0871 - val_loss: 0.0863
# Epoch 39/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0868 - val_loss: 0.0862
# Epoch 40/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0864 - val_loss: 0.0863
# Epoch 41/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0864 - val_loss: 0.0858
# Epoch 42/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0861 - val_loss: 0.0855
# Epoch 43/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0860 - val_loss: 0.0856
# Epoch 44/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0861 - val_loss: 0.0854
# Epoch 45/100
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0859 - val_loss: 0.0853
# Epoch 46/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0855 - val_loss: 0.0854
# Epoch 47/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0857 - val_loss: 0.0850
# Epoch 48/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0858 - val_loss: 0.0849
# Epoch 49/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0854 - val_loss: 0.0848
# Epoch 50/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0853 - val_loss: 0.0846
# Epoch 51/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0851 - val_loss: 0.0844
# Epoch 52/100
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0850 - val_loss: 0.0846
# Epoch 53/100
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0847 - val_loss: 0.0846
# Epoch 54/100
# 235/235 [==============================] - 2s 11ms/step - loss: 0.0848 - val_loss: 0.0842
# Epoch 55/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0845 - val_loss: 0.0842
# Epoch 56/100
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0845 - val_loss: 0.0839
# Epoch 57/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0842 - val_loss: 0.0839
# Epoch 58/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0842 - val_loss: 0.0837
# Epoch 59/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0842 - val_loss: 0.0838
# Epoch 60/100
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0839 - val_loss: 0.0836
# Epoch 61/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0840 - val_loss: 0.0833
# Epoch 62/100
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0837 - val_loss: 0.0836
# Epoch 63/100
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0837 - val_loss: 0.0834
# Epoch 64/100
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0838 - val_loss: 0.0833
# Epoch 65/100
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0836 - val_loss: 0.0833
# Epoch 66/100
# 235/235 [==============================] - 2s 11ms/step - loss: 0.0835 - val_loss: 0.0838
# Epoch 67/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0835 - val_loss: 0.0835
# Epoch 68/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0833 - val_loss: 0.0832
# Epoch 69/100
# 235/235 [==============================] - 2s 11ms/step - loss: 0.0833 - val_loss: 0.0831
# Epoch 70/100
# 235/235 [==============================] - 2s 11ms/step - loss: 0.0834 - val_loss: 0.0832
# Epoch 71/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0833 - val_loss: 0.0830
# Epoch 72/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0831 - val_loss: 0.0829
# Epoch 73/100
# 235/235 [==============================] - 2s 11ms/step - loss: 0.0831 - val_loss: 0.0830
# Epoch 74/100
# 235/235 [==============================] - 2s 11ms/step - loss: 0.0832 - val_loss: 0.0831
# Epoch 75/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0832 - val_loss: 0.0829
# Epoch 76/100
# 235/235 [==============================] - 2s 11ms/step - loss: 0.0829 - val_loss: 0.0827
# Epoch 77/100
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0830 - val_loss: 0.0829
# Epoch 78/100
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0830 - val_loss: 0.0827
# Epoch 79/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0827 - val_loss: 0.0827
# Epoch 80/100
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0829 - val_loss: 0.0826
# Epoch 81/100
# 235/235 [==============================] - 2s 11ms/step - loss: 0.0828 - val_loss: 0.0825
# Epoch 82/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0828 - val_loss: 0.0826
# Epoch 83/100
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0827 - val_loss: 0.0825
# Epoch 84/100
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0827 - val_loss: 0.0824
# Epoch 85/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0827 - val_loss: 0.0823
# Epoch 86/100
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0827 - val_loss: 0.0824
# Epoch 87/100
# 235/235 [==============================] - 2s 11ms/step - loss: 0.0825 - val_loss: 0.0826
# Epoch 88/100
# 235/235 [==============================] - 2s 11ms/step - loss: 0.0827 - val_loss: 0.0824
# Epoch 89/100
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0825 - val_loss: 0.0825
# Epoch 90/100
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0825 - val_loss: 0.0823
# Epoch 91/100
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0825 - val_loss: 0.0822
# Epoch 92/100
# 235/235 [==============================] - 2s 11ms/step - loss: 0.0823 - val_loss: 0.0823
# Epoch 93/100
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0824 - val_loss: 0.0823
# Epoch 94/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0826 - val_loss: 0.0824
# Epoch 95/100
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0823 - val_loss: 0.0826
# Epoch 96/100
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0824 - val_loss: 0.0822
# Epoch 97/100
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0823 - val_loss: 0.0822
# Epoch 98/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0824 - val_loss: 0.0823
# Epoch 99/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0823 - val_loss: 0.0821
# Epoch 100/100
# 235/235 [==============================] - 2s 11ms/step - loss: 0.0822 - val_loss: 0.0820

# %%
import keras
from keras import layers

input_img = keras.Input(shape=(28, 28, 1))

x = layers.Conv2D(16, (3, 3), activation='relu', padding='same')(input_img)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
encoded = layers.MaxPooling2D((2, 2), padding='same')(x)

# at this point the representation is (4, 4, 8) i.e. 128-dimensional

x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(encoded)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2D(16, (3, 3), activation='relu')(x)
x = layers.UpSampling2D((2, 2))(x)
decoded = layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = keras.Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# %%
from keras.datasets import mnist
import numpy as np

(x_train, _), (x_test, _) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = np.reshape(x_train, (len(x_train), 28, 28, 1))
x_test = np.reshape(x_test, (len(x_test), 28, 28, 1))

# %%
from keras.callbacks import TensorBoard

autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=128,
                shuffle=True,
                validation_data=(x_test, x_test),
                callbacks=[TensorBoard(log_dir='/tmp/autoencoder')])
# Out:
# Epoch 1/50
# 469/469 [==============================] - 58s 114ms/step - loss: 0.3123 - val_loss: 0.1447
# Epoch 2/50
# 469/469 [==============================] - 52s 111ms/step - loss: 0.1388 - val_loss: 0.1260
# Epoch 3/50
# 469/469 [==============================] - 53s 113ms/step - loss: 0.1249 - val_loss: 0.1181
# Epoch 4/50
# 469/469 [==============================] - 52s 110ms/step - loss: 0.1189 - val_loss: 0.1144
# Epoch 5/50
# 469/469 [==============================] - 52s 111ms/step - loss: 0.1150 - val_loss: 0.1114
# Epoch 6/50
# 469/469 [==============================] - 54s 116ms/step - loss: 0.1119 - val_loss: 0.1093
# Epoch 7/50
# 469/469 [==============================] - 51s 109ms/step - loss: 0.1102 - val_loss: 0.1082
# Epoch 8/50
# 469/469 [==============================] - 51s 109ms/step - loss: 0.1083 - val_loss: 0.1060
# Epoch 9/50
# 469/469 [==============================] - 55s 116ms/step - loss: 0.1072 - val_loss: 0.1047
# Epoch 10/50
# 469/469 [==============================] - 54s 114ms/step - loss: 0.1058 - val_loss: 0.1038
# Epoch 11/50
# 469/469 [==============================] - 53s 113ms/step - loss: 0.1049 - val_loss: 0.1031
# Epoch 12/50
# 469/469 [==============================] - 51s 109ms/step - loss: 0.1036 - val_loss: 0.1023
# Epoch 13/50
# 469/469 [==============================] - 51s 108ms/step - loss: 0.1030 - val_loss: 0.1016
# Epoch 14/50
# 469/469 [==============================] - 51s 109ms/step - loss: 0.1021 - val_loss: 0.1006
# Epoch 15/50
# 469/469 [==============================] - 52s 111ms/step - loss: 0.1016 - val_loss: 0.0998
# Epoch 16/50
# 469/469 [==============================] - 53s 113ms/step - loss: 0.1010 - val_loss: 0.0992
# Epoch 17/50
# 469/469 [==============================] - 52s 111ms/step - loss: 0.1001 - val_loss: 0.0986
# Epoch 18/50
# 469/469 [==============================] - 51s 110ms/step - loss: 0.0996 - val_loss: 0.0981
# Epoch 19/50
# 469/469 [==============================] - 54s 114ms/step - loss: 0.0994 - val_loss: 0.0977
# Epoch 20/50
# 469/469 [==============================] - 56s 120ms/step - loss: 0.0986 - val_loss: 0.0971
# Epoch 21/50
# 469/469 [==============================] - 57s 122ms/step - loss: 0.0983 - val_loss: 0.0968
# Epoch 22/50
# 469/469 [==============================] - 56s 120ms/step - loss: 0.0979 - val_loss: 0.0969
# Epoch 23/50
# 469/469 [==============================] - 55s 116ms/step - loss: 0.0974 - val_loss: 0.0962
# Epoch 24/50
# 469/469 [==============================] - 52s 110ms/step - loss: 0.0973 - val_loss: 0.0959
# Epoch 25/50
# 469/469 [==============================] - 52s 111ms/step - loss: 0.0968 - val_loss: 0.0959
# Epoch 26/50
# 469/469 [==============================] - 56s 119ms/step - loss: 0.0964 - val_loss: 0.0951
# Epoch 27/50
# 469/469 [==============================] - 56s 119ms/step - loss: 0.0962 - val_loss: 0.0945
# Epoch 28/50
# 469/469 [==============================] - 56s 119ms/step - loss: 0.0959 - val_loss: 0.0947
# Epoch 29/50
# 469/469 [==============================] - 56s 119ms/step - loss: 0.0956 - val_loss: 0.0940
# Epoch 30/50
# 469/469 [==============================] - 56s 119ms/step - loss: 0.0954 - val_loss: 0.0952
# Epoch 31/50
# 469/469 [==============================] - 54s 114ms/step - loss: 0.0952 - val_loss: 0.0943
# Epoch 32/50
# 469/469 [==============================] - 55s 118ms/step - loss: 0.0950 - val_loss: 0.0937
# Epoch 33/50
# 469/469 [==============================] - 59s 126ms/step - loss: 0.0945 - val_loss: 0.0935
# Epoch 34/50
# 469/469 [==============================] - 51s 109ms/step - loss: 0.0947 - val_loss: 0.0933
# Epoch 35/50
# 469/469 [==============================] - 59s 127ms/step - loss: 0.0945 - val_loss: 0.0932
# Epoch 36/50
# 469/469 [==============================] - 51s 110ms/step - loss: 0.0942 - val_loss: 0.0928
# Epoch 37/50
# 469/469 [==============================] - 52s 111ms/step - loss: 0.0941 - val_loss: 0.0927
# Epoch 38/50
# 469/469 [==============================] - 52s 112ms/step - loss: 0.0940 - val_loss: 0.0924
# Epoch 39/50
# 469/469 [==============================] - 51s 109ms/step - loss: 0.0937 - val_loss: 0.0922
# Epoch 40/50
# 469/469 [==============================] - 54s 114ms/step - loss: 0.0935 - val_loss: 0.0923
# Epoch 41/50
# 469/469 [==============================] - 56s 118ms/step - loss: 0.0933 - val_loss: 0.0922
# Epoch 42/50
# 469/469 [==============================] - 56s 120ms/step - loss: 0.0933 - val_loss: 0.0919
# Epoch 43/50
# 469/469 [==============================] - 52s 111ms/step - loss: 0.0929 - val_loss: 0.0922
# Epoch 44/50
# 469/469 [==============================] - 52s 111ms/step - loss: 0.0929 - val_loss: 0.0915
# Epoch 45/50
# 469/469 [==============================] - 56s 119ms/step - loss: 0.0927 - val_loss: 0.0913
# Epoch 46/50
# 469/469 [==============================] - 59s 125ms/step - loss: 0.0926 - val_loss: 0.0912
# Epoch 47/50
# 469/469 [==============================] - 55s 117ms/step - loss: 0.0927 - val_loss: 0.0911
# Epoch 48/50
# 469/469 [==============================] - 62s 131ms/step - loss: 0.0924 - val_loss: 0.0913
# Epoch 49/50
# 469/469 [==============================] - 60s 128ms/step - loss: 0.0922 - val_loss: 0.0908
# Epoch 50/50
# 469/469 [==============================] - 60s 127ms/step - loss: 0.0921 - val_loss: 0.0910

# %%
decoded_imgs = autoencoder.predict(x_test)

n = 10
plt.figure(figsize=(20, 4))
for i in range(1, n + 1):
    # Display original
    ax = plt.subplot(2, n, i)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
encoder = keras.Model(input_img, encoded)
encoded_imgs = encoder.predict(x_test)

n = 10
plt.figure(figsize=(20, 8))
for i in range(1, n + 1):
    ax = plt.subplot(1, n, i)
    plt.imshow(encoded_imgs[i].reshape((4, 4 * 8)).T)
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
from keras.datasets import mnist
import numpy as np

(x_train, _), (x_test, _) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = np.reshape(x_train, (len(x_train), 28, 28, 1))
x_test = np.reshape(x_test, (len(x_test), 28, 28, 1))

noise_factor = 0.5
x_train_noisy = x_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape) 
x_test_noisy = x_test + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape) 

x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)

# %%
n = 10
plt.figure(figsize=(20, 2))
for i in range(1, n + 1):
    ax = plt.subplot(1, n, i)
    plt.imshow(x_test_noisy[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
input_img = keras.Input(shape=(28, 28, 1))

x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(input_img)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
encoded = layers.MaxPooling2D((2, 2), padding='same')(x)

# At this point the representation is (7, 7, 32)

x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(encoded)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = layers.UpSampling2D((2, 2))(x)
decoded = layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = keras.Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# %%
autoencoder.fit(x_train_noisy, x_train,
                epochs=100,
                batch_size=128,
                shuffle=True,
                validation_data=(x_test_noisy, x_test),
                callbacks=[TensorBoard(log_dir='/tmp/tb', histogram_freq=0, write_graph=False)])
